# %% [markdown]
# #### Loading Dataset

# %%
# To Avoid Warnings
import warnings
warnings.filterwarnings("ignore")

#importing the Libraies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

dataset = pd.read_csv("50_Startups.csv")
dataset.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
print("Columns:",[i for i in dataset.columns])
# Out:
# Columns: ['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit']

# %% [markdown]
# #### Converting Categorical to Numerical Column

# %%
dataset = (pd.get_dummies(dataset,drop_first=True)).astype(int)
dataset.head()
# Out:
#    R&D Spend  Administration  Marketing Spend  Profit  State_Florida  \
# 0     165349          136897           471784  192261              0
# 1     162597          151377           443898  191792              0
# 2     153441          101145           407934  191050              1
# 3     144372          118671           383199  182901              0
# 4     142107           91391           366168  166187              1
#
#    State_New York
# 0               1
# 1               0
# 2               0
# 3               1
# 4               0

# %% [markdown]
# #### Assigning Input and Output Variables (5 i/p & 1 o/p)

# %%
independent=dataset[['R&D Spend', 'Administration', 'Marketing Spend','State_Florida', 'State_New York']]
independent.head()
# Out:
#    R&D Spend  Administration  Marketing Spend  State_Florida  State_New York
# 0     165349          136897           471784              0               1
# 1     162597          151377           443898              0               0
# 2     153441          101145           407934              1               0
# 3     144372          118671           383199              0               1
# 4     142107           91391           366168              1               0

# %%
dependent=dataset[["Profit"]]
dependent.head()
# Out:
#    Profit
# 0  192261
# 1  191792
# 2  191050
# 3  182901
# 4  166187

# %% [markdown]
# #### Split of Data into Train and Test

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent, dependent, test_size=1/3,random_state=47)

# %%
X_train.head(2)
# Out:
#     R&D Spend  Administration  Marketing Spend  State_Florida  State_New York
# 10     101913          110594           229160              1               0
# 11     100671           91790           249744              0               0

# %%
y_train.head(2)
# Out:
#     Profit
# 10  146121
# 11  144259

# %% [markdown]
# #### Normalizing input data using Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train) # fit - the mean and standard deviation values are calculated
X_test=sc.transform(X_test) # transform - the same calculated mean and standard deviation are applied and transformed

# %%
pd.DataFrame(X_train).head(2)
# Out:
#           0         1         2         3         4
# 0  0.413943 -0.415510  0.040548  1.414214 -0.755929
# 1  0.390320 -1.075887  0.192651 -0.707107 -0.755929

# %% [markdown]
# #### Training Model using Train Data (X_train, y_train)

# %% [markdown]
# ##### Random Forest is helpful in obtaining result from many decision trees, and providing the majority answer from all the calculated trees' answers.

# %%
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor(n_estimators=100,criterion='friedman_mse',max_features='sqrt')
regressor=regressor.fit(X_train,y_train)

# %%
print("Features Importances: ",regressor.feature_importances_)
print("N-Features : ",regressor.n_features_in_)
# Out:
# Features Importances:  [0.54348712 0.12139684 0.30620099 0.01587224 0.01304281]
# N-Features :  5

# %% [markdown]
# #### Example Predicting using X_test

# %%
y_pred=regressor.predict(X_test)
(pd.DataFrame(y_pred)).head()
# Out:
#            0
# 0   76832.68
# 1   82387.47
# 2   85641.53
# 3  132107.89
# 4   90036.75

# %%
(pd.DataFrame(y_test)).head()
# Out:
#     Profit
# 40   78239
# 42   71498
# 32   97427
# 13  134307
# 39   81005

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
print("R2-Score:",r_score)
# Out:
# R2-Score: 0.7154834519660941

# %% [markdown]
# #### Saving Trained Model

# %%
import pickle
filename="Random_Forest.sav"
pickle.dump(regressor,open(filename,"wb"))
