# %% [markdown]
# Importing the cleaned dataset

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
df = pd.read_csv('cleaned_data.csv')

# %% [markdown]
# Selecting the first feature - Age

# %%
independent = df[['age']]
dependent = df[['charges']]

X_train,X_test,y_train,y_test=train_test_split(independent, dependent, test_size=1/3,random_state=43)

regressor = LinearRegression()
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)

r_score = r2_score(y_test,y_pred)
print("R-score:",r_score)
# Out:
# 0.07814855983727376

# %% [markdown]
# Selecting the Second Feature - Sex

# %%
independent = df[['sex']]

X_train,X_test,y_train,y_test=train_test_split(independent, dependent, test_size=1/3,random_state=43)

regressor = LinearRegression()
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)

r_score = r2_score(y_test,y_pred)
print("R-score:",r_score)
# Out:
# -0.013355500985102964

# %% [markdown]
# Selecting the Third Feature - BMI

# %%
independent = df[['bmi']]

X_train,X_test,y_train,y_test=train_test_split(independent, dependent, test_size=1/3,random_state=43)

regressor = LinearRegression()
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)

r_score = r2_score(y_test,y_pred)
print("R-score:",r_score)
# Out:
# 0.025893503299249554

# %% [markdown]
# Selecting the Fourth Feature - Children

# %%
independent = df[['children']]

X_train,X_test,y_train,y_test=train_test_split(independent, dependent, test_size=1/3,random_state=43)

regressor = LinearRegression()
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)

r_score = r2_score(y_test,y_pred)
print("R-score:",r_score)
# Out:
# -0.0090675312951769

# %% [markdown]
# Selecting the Fifth Feature - smoker

# %%
independent = df[['smoker']]

X_train,X_test,y_train,y_test=train_test_split(independent, dependent, test_size=1/3,random_state=43)

regressor = LinearRegression()
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)

r_score = r2_score(y_test,y_pred)
print("R-score:",r_score)
# Out:
# 0.6089153529466211
